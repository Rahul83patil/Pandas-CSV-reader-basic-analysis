# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns=['A','B','C'], index=['X','Y','Z'])

# %%
df.head()
# Out:
#    A  B  C
# X  1  2  3
# Y  4  5  6
# Z  7  8  9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, X to Z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.nunique()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df['A'].unique()
# Out:
# array([1, 4, 7], dtype=int64)

# %%
df.shape
# Out:
# (3, 3)

# %%
df.size
# Out:
# 9

# %%
df
# Out:
#    A  B  C
# X  1  2  3
# Y  4  5  6
# Z  7  8  9

# %% [markdown]
# loading in Dataframes from files

# %%
coffee = pd.read_csv('./warmup-data/coffee.csv')

# %%
results = pd.read_parquet('./data/results.parquet')
bios = pd.read_csv('./data/bios.csv')

# %%
olympics_data = pd.read_excel('./data/olympics-data.xlsx', sheet_name='results')

# %% [markdown]
# Accessing Data with Pandas

# %%
print(coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
display(coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.tail(10)
# Out:
#           Day Coffee Type  Units Sold
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.sample(5)
# Out:
#           Day Coffee Type  Units Sold
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 2     Tuesday    Espresso          30
# 4   Wednesday    Espresso          35
# 8      Friday    Espresso          45

# %%
coffee.loc[0]
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
coffee.loc[[0,1,5]]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 5  Wednesday       Latte          25

# %%
coffee.loc[5:9,["Day","Units Sold"]]
# Out:
#          Day  Units Sold
# 5  Wednesday          25
# 6   Thursday          40
# 7   Thursday          30
# 8     Friday          45
# 9     Friday          35

# %%
coffee.iloc[:, [0,2]]
# Out:
#           Day  Units Sold
# 0      Monday          25
# 1      Monday          15
# 2     Tuesday          30
# 3     Tuesday          20
# 4   Wednesday          35
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45
# 11   Saturday          35
# 12     Sunday          45
# 13     Sunday          35

# %%
coffee.index = coffee["Day"]

# %%
coffee.loc['Monday':'Wednesday']
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          15
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35
# Wednesday  Wednesday       Latte          25

# %%
coffee = pd.read_csv('./warmup-data/coffee.csv')

# %% [markdown]
# Setting Values

# %%
coffee.loc[1:3, "Units Sold"] = 10

# %% [markdown]
# Optimized way to get single values (.at & .iat)

# %%
coffee.at[0,"Units Sold"]
# Out:
# 25

# %%
coffee.iat[3,1]
# Out:
# 'Latte'

# %% [markdown]
# Getting Columns

# %%
coffee.Day
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
coffee["Day"]
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %% [markdown]
# Sort Values

# %%
coffee.sort_values(['Units Sold'], ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          10
# 3     Tuesday       Latte          10

# %%
coffee.sort_values(['Units Sold','Coffee Type'], ascending=[0,1])
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          10
# 1      Monday       Latte          10
# 3     Tuesday       Latte          10

# %%
for index, row in  coffee.iterrows():
    print(index)
    print(row)
    print("Coffee type of Row:", row["Coffee Type"])
# Out:
# 0
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
# Coffee type of Row: Espresso
# 1
# Day            Monday
# Coffee Type     Latte
# Units Sold         10
# Name: 1, dtype: object
# Coffee type of Row: Latte
# 2
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           10
# Name: 2, dtype: object
# Coffee type of Row: Espresso
# 3
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          10
# Name: 3, dtype: object
# Coffee type of Row: Latte
# 4
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# Name: 4, dtype: object
# Coffee type of Row: Espresso
# 5
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# Name: 5, dtype: object
# Coffee type of Row: Latte
# 6
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: 6, dtype: object
# Coffee type of Row: Espresso
# 7
# Day            Thursday
# Coffee Type       Latte
# Units Sold           30
# Name: 7, dtype: object
# Coffee type of Row: Latte
# 8
# Day              Friday
# Coffee Type    Espresso
# Units Sold           45
# Name: 8, dtype: object
# Coffee type of Row: Espresso
# 9
# Day            Friday
# Coffee Type     Latte
# Units Sold         35
# Name: 9, dtype: object
# Coffee type of Row: Latte
# 10
# Day            Saturday
# Coffee Type    Espresso
# Units Sold           45
# Name: 10, dtype: object
# Coffee type of Row: Espresso
# 11
# Day            Saturday
# Coffee Type       Latte
# Units Sold           35
# Name: 11, dtype: object
# Coffee type of Row: Latte
# 12
# Day              Sunday
# Coffee Type    Espresso
# Units Sold           45
# Name: 12, dtype: object
# Coffee type of Row: Espresso
# 13
# Day            Sunday
# Coffee Type     Latte
# Units Sold         35
# Name: 13, dtype: object
# Coffee type of Row: Latte

# %% [markdown]
# Filtering Data

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.loc[bios["height_cm"]> 215]
# Out:
#         athlete_id                   name   born_date               born_city  \
# 5089          5108     Viktor Pankrashkin  1957-06-19         Moskva (Moscow)
# 5583          5606   Paulinho Villas Boas  1963-01-26               São Paulo
# 5673          5696         Gunther Behnke  1963-01-19              Leverkusen
# 5716          5739               Uwe Blab  1962-03-26        München (Munich)
# 5781          5804         Tommy Burleson  1952-02-24               Crossnore
# 5796          5819          Andy Campbell  1956-07-21               Melbourne
# 6223          6250            Lars Hansen  1954-09-27  København (Copenhagen)
# 6270          6298            Hu Zhangbao  1963-04-05                     NaN
# 6409          6440       Sergey Kovalenko  1947-08-11                     NaN
# 6420          6451          Jānis Krūmiņš  1930-01-30                   Cēsis
# 6504          6537            Luc Longley  1969-01-19               Melbourne
# 6722          6755       Shaquille O'Neal  1972-03-06                  Newark
# 6937          6972         David Robinson  1965-08-06                Key West
# 6978          7013        Arvydas Sabonis  1964-12-19                  Kaunas
# 7074          7111         Paulo da Silva  1963-07-21               São Paulo
# 7188          7226     Vladimir Tkachenko  1957-09-20               Golovinka
# 7281          7320       Stojko Vranković  1964-01-22                   Drniš
# 7376          7416    Eurelijus Žukauskas  1973-08-22                Klaipėda
# 52608        52983        Aleksey Kazakov  1976-03-18      Naberezhnye Chelny
# 82100        82753          Frédéric Weis  1977-06-22              Thionville
# 89070        89782               Yao Ming  1980-09-12          Xuhui District
# 89075        89787         Roberto Dueñas  1975-11-01                  Madrid
# 107408      108533       Peter John Ramos  1985-05-23                 Fajardo
# 112312      113568           Stanko Barać  1986-08-13                  Mostar
# 112332      113588    Andreas Glyniadakis  1981-08-26                  Chania
# 112337      113593          Hamed Haddadi  1985-05-19                   Ahvaz
# 118663      120400         Timofey Mozgov  1986-07-16                     NaN
# 118676      120415        Dmitry Musersky  1988-10-29                Makiïvka
# 120266      122147           Zhang Zhaoxu  1987-11-18                 Binzhou
# 121694      123709            Salah Mejri  1986-06-15                Jendouba
# 123850      126093         Tyson Chandler  1982-10-02                 Hanford
# 130460      133147               Li Muhao  1992-06-02                 Guiyang
# 130461      133148                Zhou Qi  1996-01-16                Xinxiang
# 138671      142084          Ondřej Balvín  1992-09-20          Ústí nad Labem
# 139365      142836         Moustapha Fall  1992-02-23                   Paris
#
#                             born_region born_country  \
# 5089                             Moskva          RUS
# 5583                          São Paulo          BRA
# 5673                Nordrhein-Westfalen          GER
# 5716                             Bayern          GER
# 5781                     North Carolina          USA
# 5796                           Victoria          AUS
# 6223                        Hovedstaden          DEN
# 6270                                NaN          NaN
# 6409                                NaN          NaN
# 6420                        Cēsu novads          LAT
# 6504                           Victoria          AUS
# 6722                         New Jersey          USA
# 6937                            Florida          USA
# 6978                             Kaunas          LTU
# 7074                          São Paulo          BRA
# 7188                     Krasnodar Kray          RUS
# 7281          Šibensko-kninska županija          CRO
# 7376                           Klaipėda          LTU
# 52608              Respublika Tatarstan          RUS
# 82100                           Moselle          FRA
# 89070                          Shanghai          CHN
# 89075                            Madrid          ESP
# 107408                      Puerto Rico          PUR
# 112312  Hercegovačko-neretvanski kanton          BIH
# 112332                            Kriti          GRE
# 112337                        Khuzestan          IRI
# 118663                              NaN          NaN
# 118676                          Donetsk          UKR
# 120266                         Shandong          CHN
# 121694                         Jendouba          TUN
# 123850                       California          USA
# 130460                          Guizhou          CHN
# 130461                            Henan          CHN
# 138671                     Ústecký kraj          CZE
# 139365                            Paris          FRA
#
#                                NOC  height_cm  weight_kg   died_date
# 5089                  Soviet Union      220.0      112.0  1993-07-24
# 5583                        Brazil      217.0      106.0         NaN
# 5673                       Germany      221.0      114.0         NaN
# 5716          Germany West Germany      218.0      110.0         NaN
# 5781                 United States      223.0      102.0         NaN
# 5796                     Australia      218.0       93.0         NaN
# 6223                        Canada      216.0      105.0         NaN
# 6270    People's Republic of China      216.0      135.0         NaN
# 6409                  Soviet Union      216.0      111.0  2004-11-18
# 6420                  Soviet Union      218.0      141.0  1994-11-20
# 6504                     Australia      220.0      135.0         NaN
# 6722                 United States      216.0      137.0         NaN
# 6937                 United States      216.0      107.0         NaN
# 6978        Lithuania Soviet Union      223.0      122.0         NaN
# 7074                        Brazil      217.0      106.0         NaN
# 7188                  Soviet Union      220.0      110.0         NaN
# 7281            Croatia Yugoslavia      217.0      115.0         NaN
# 7376                     Lithuania      218.0      115.0         NaN
# 52608           Russian Federation      217.0      102.0         NaN
# 82100                       France      218.0      110.0         NaN
# 89070   People's Republic of China      226.0      141.0         NaN
# 89075                        Spain      221.0      137.0         NaN
# 107408                 Puerto Rico      219.0      113.0         NaN
# 112312                     Croatia      217.0      110.0         NaN
# 112332                      Greece      216.0      115.0         NaN
# 112337    Islamic Republic of Iran      218.0      110.0         NaN
# 118663          Russian Federation      216.0      113.0         NaN
# 118676          Russian Federation      219.0      104.0         NaN
# 120266  People's Republic of China      221.0      110.0         NaN
# 121694                     Tunisia      216.0      110.0         NaN
# 123850               United States      216.0      107.0         NaN
# 130460  People's Republic of China      218.0      115.0         NaN
# 130461  People's Republic of China      217.0       95.0         NaN
# 138671                     Czechia      216.0      107.0         NaN
# 139365                      France      218.0        NaN         NaN

# %%
bios.loc[bios['height_cm']> 215, ['name', 'height_cm']]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# 107408       Peter John Ramos      219.0
# 112312           Stanko Barać      217.0
# 112332    Andreas Glyniadakis      216.0
# 112337          Hamed Haddadi      218.0
# 118663         Timofey Mozgov      216.0
# 118676        Dmitry Musersky      219.0
# 120266           Zhang Zhaoxu      221.0
# 121694            Salah Mejri      216.0
# 123850         Tyson Chandler      216.0
# 130460               Li Muhao      218.0
# 130461                Zhou Qi      217.0
# 138671          Ondřej Balvín      216.0
# 139365         Moustapha Fall      218.0

# %% [markdown]
# Short-hand syntax (without.loc)

# %%
bios[bios['height_cm'] > 215] [['name', 'height_cm']]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# 107408       Peter John Ramos      219.0
# 112312           Stanko Barać      217.0
# 112332    Andreas Glyniadakis      216.0
# 112337          Hamed Haddadi      218.0
# 118663         Timofey Mozgov      216.0
# 118676        Dmitry Musersky      219.0
# 120266           Zhang Zhaoxu      221.0
# 121694            Salah Mejri      216.0
# 123850         Tyson Chandler      216.0
# 130460               Li Muhao      218.0
# 130461                Zhou Qi      217.0
# 138671          Ondřej Balvín      216.0
# 139365         Moustapha Fall      218.0

# %% [markdown]
# Multiple filter condition

# %%
bios[(bios['height_cm'] > 215) & (bios['born_country']=='USA')]
# Out:
#         athlete_id              name   born_date  born_city     born_region  \
# 5781          5804    Tommy Burleson  1952-02-24  Crossnore  North Carolina
# 6722          6755  Shaquille O'Neal  1972-03-06     Newark      New Jersey
# 6937          6972    David Robinson  1965-08-06   Key West         Florida
# 123850      126093    Tyson Chandler  1982-10-02    Hanford      California
#
#        born_country            NOC  height_cm  weight_kg died_date
# 5781            USA  United States      223.0      102.0       NaN
# 6722            USA  United States      216.0      137.0       NaN
# 6937            USA  United States      216.0      107.0       NaN
# 123850          USA  United States      216.0      107.0       NaN

# %% [markdown]
# Filter by string

# %%
bios[bios['name'].str.contains("keith", case=False)]
# Out:
#         athlete_id                  name   born_date         born_city  \
# 1897          1907          Keith Hanlon  1966-09-01               NaN
# 3505          3517         Keith Wallace  1961-03-29           Preston
# 6228          6255         Keith Hartley  1940-10-15         Vancouver
# 8898          8946           Keith Mwila  1966-01-01               NaN
# 12053        12118          Keith Hervey  1898-11-03            Fulham
# ...            ...                   ...         ...               ...
# 109900      111105     Keith Cumberpatch  1927-08-25      Christchurch
# 115973      117348       Keith Sanderson  1975-02-02          Plymouth
# 117676      119195          Duncan Keith  1983-07-16          Winnipeg
# 122121      124176        Keith Ferguson  1979-09-07              Sale
# 127310      129749  Tracy Keith-Matchitt  1990-03-30  Palmerston North
#
#               born_region born_country            NOC  height_cm  weight_kg  \
# 1897                  NaN          NaN        Ireland        NaN        NaN
# 3505              England          GBR  Great Britain      165.0       51.0
# 6228     British Columbia          CAN         Canada      200.0       85.0
# 8898                  NaN          NaN         Zambia        NaN        NaN
# 12053             England          GBR  Great Britain        NaN        NaN
# ...                   ...          ...            ...        ...        ...
# 109900         Canterbury          NZL    New Zealand        NaN        NaN
# 115973      Massachusetts          USA  United States      183.0       95.0
# 117676           Manitoba          CAN         Canada      185.0       88.0
# 122121           Victoria          AUS      Australia      176.0       78.0
# 127310  Manawatu-Wanganui          NZL   Cook Islands      167.0       60.0
#
#          died_date
# 1897           NaN
# 3505    1999-12-31
# 6228           NaN
# 8898    1993-01-09
# 12053   1973-02-22
# ...            ...
# 109900  2013-11-15
# 115973         NaN
# 117676         NaN
# 122121         NaN
# 127310         NaN
#
# [70 rows x 10 columns]

# %%
bios[bios['name'].str.contains("keith|patrick", case=False)]
# Out:
#         athlete_id               name   born_date              born_city  \
# 6                7      Patrick Chila  1969-11-27            Ris-Orangis
# 119            120   Patrick Wheatley  1899-01-20                Vryheid
# 319            320  Patrick De Koning  1961-04-23            Dendermonde
# 1897          1907       Keith Hanlon  1966-09-01                    NaN
# 2115          2125       Patrick Jopp  1962-01-08                    NaN
# ...            ...                ...         ...                    ...
# 143975      147633  Patrick Chinyemba  2001-01-03                    NaN
# 144172      147850      Patrick Jakob  1996-10-17  Sankt Johann in Tirol
# 144547      148239  Patrick Galbraith  1986-03-11              Haderslev
# 144565      148257    Patrick Russell  1993-01-04               Gentofte
# 145435      149158  Patrick Gasienica  1998-11-28                McHenry
#
#             born_region born_country            NOC  height_cm  weight_kg  \
# 6               Essonne          FRA         France      180.0       73.0
# 119       KwaZulu-Natal          RSA  Great Britain        NaN        NaN
# 319     Oost-Vlaanderen          BEL        Belgium      178.0       92.0
# 1897                NaN          NaN        Ireland        NaN        NaN
# 2115                NaN          NaN    Switzerland      176.0       67.0
# ...                 ...          ...            ...        ...        ...
# 143975              NaN          NaN         Zambia        NaN        NaN
# 144172            Tirol          AUT        Austria        NaN        NaN
# 144547       Syddanmark          DEN        Denmark        NaN        NaN
# 144565      Hovedstaden          DEN        Denmark      186.0       93.0
# 145435         Illinois          USA  United States        NaN        NaN
#
#          died_date
# 6              NaN
# 119     1967-11-05
# 319            NaN
# 1897           NaN
# 2115           NaN
# ...            ...
# 143975         NaN
# 144172         NaN
# 144547         NaN
# 144565         NaN
# 145435  2023-06-12
#
# [303 rows x 10 columns]

# %%
vowel_cities = bios[bios['born_city'].str.contains(r'^[AEIOUaeiou]', na=False)]

two_vowels = bios[bios['name'].str.contains(r'^[^AEIOUaeiou]*[AEIOUaeiou][^AEIOUaeiou]*[AEIOUaeiou][^AEIOUaeiou]*$', na=False)]

repeated_letters = bios[bios['name'].str.contains(r'(.)\1', na=False)]

son_sen_names = bios[bios['name'].str.contains(r'son$|sen$', case=False, na=False)]

born_19xx = bios[bios['born_date'].str.contains(r'^19', na=False)]

no_vowels = bios[bios['name'].str.contains(r'^[^AEIOUaeiou]*$', na=False)]

hyphen_apostrophe = bios[bios['name'].str.contains(r"[-']", na=False)]

start_end_same = bios[bios['name'].str.contains(r'^(.).*\1$', na=False, case=False)]

city_seven_chars = bios[bios['born_city'].str.contains(r'^.{7}$', na=False)]

three_or_more_vowels = bios[bios['name'].str.contains(r'([AEIOUaeiou].*){3,}', na=False)]
# Out:
# C:\Users\RAHUL KATE\AppData\Local\Temp\ipykernel_13240\399742436.py:5: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   repeated_letters = bios[bios['name'].str.contains(r'(.)\1', na=False)]
# C:\Users\RAHUL KATE\AppData\Local\Temp\ipykernel_13240\399742436.py:15: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   start_end_same = bios[bios['name'].str.contains(r'^(.).*\1$', na=False, case=False)]
# C:\Users\RAHUL KATE\AppData\Local\Temp\ipykernel_13240\399742436.py:19: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   three_or_more_vowels = bios[bios['name'].str.contains(r'([AEIOUaeiou].*){3,}', na=False)]

# %%
bios[bios['name'].str.contains('keith|patrick', case=False, regex =False)]
# Out:
# Empty DataFrame
# Columns: [athlete_id, name, born_date, born_city, born_region, born_country, NOC, height_cm, weight_kg, died_date]
# Index: []

# %%
bios[bios['born_country'].isin(["USA", "FRA", "GBR"]) & (bios['name'].str.startswith("Keith"))]
# Out:
#         athlete_id                name   born_date             born_city  \
# 3505          3517       Keith Wallace  1961-03-29               Preston
# 12053        12118        Keith Hervey  1898-11-03                Fulham
# 14577        14674      Keith Harrison  1933-03-28            Birmingham
# 16166        16281      Keith Reynolds  1963-12-25              Solihull
# 18734        18862      Keith Sinclair  1945-06-26            Sunderland
# 29897        30123       Keith Langley  1961-06-03             Aldershot
# 34011        34275        Keith Remfry  1947-11-17                Ealing
# 46885        47234        Keith Collin  1937-01-18            Marylebone
# 50929        51288        Keith Carter  1924-08-30                 Akron
# 51185        51544       Keith Russell  1948-01-15                  Mesa
# 52913        53288      Keith Erickson  1944-04-19         San Francisco
# 55317        55712        Keith Boxell  1958-05-06               Clapham
# 57818        58226        Keith Peache  1947-08-10              Lewisham
# 61748        62202       Keith Grogono  1912-11-04             Stratford
# 62620        63086         Keith Musto  1936-01-12              Rochford
# 62678        63144        Keith Notary  1960-01-22        Merritt Island
# 68324        68841         Keith Angus  1943-04-05             Sheffield
# 68472        68989        Keith Cullen  1972-06-13                Ilford
# 68997        69514         Keith Stock  1957-03-18              Woolwich
# 77550        78141       Keith Brantly  1962-05-23  Scott Air Force Base
# 84097        84766  Keith Christiansen  1944-07-14   International Falls
# 94646        95413         Keith Meyer  1938-06-20                Geneva
# 95267        96037        Keith Oliver  1947-10-27             Liverpool
# 96452        97229  Keith Schellenberg  1929-03-13         Middlesbrough
# 97499        98286       Keith Tkachuk  1972-03-28               Melrose
# 98068        98860       Keith Wegeman  1929-08-28                Denver
# 99921       100722        Keith Carney  1970-02-03            Providence
# 115973      117348     Keith Sanderson  1975-02-02              Plymouth
#
#           born_region born_country            NOC  height_cm  weight_kg  \
# 3505          England          GBR  Great Britain      165.0       51.0
# 12053         England          GBR  Great Britain        NaN        NaN
# 14577         England          GBR  Great Britain        NaN        NaN
# 16166         England          GBR  Great Britain      173.0       68.0
# 18734         England          GBR  Great Britain      190.0       79.0
# 29897         England          GBR  Great Britain      173.0       70.0
# 34011         England          GBR  Great Britain      193.0      114.0
# 46885         England          GBR  Great Britain      168.0       63.0
# 50929            Ohio          USA  United States        NaN        NaN
# 51185         Arizona          USA  United States      188.0       73.0
# 52913      California          USA  United States      196.0       86.0
# 55317         England          GBR  Great Britain      170.0       87.0
# 57818         England          GBR  Great Britain      180.0       98.0
# 61748         England          GBR  Great Britain        NaN        NaN
# 62620         England          GBR  Great Britain      174.0       72.0
# 62678         Florida          USA  United States      170.0       66.0
# 68324         England          GBR  Great Britain      170.0       59.0
# 68472         England          GBR  Great Britain      177.0       61.0
# 68997         England          GBR  Great Britain      176.0       73.0
# 77550        Illinois          USA  United States      180.0       64.0
# 84097       Minnesota          USA  United States      165.0       69.0
# 94646        Illinois          USA  United States        NaN        NaN
# 95267         England          GBR  Great Britain      172.0       68.0
# 96452         England          GBR  Great Britain        NaN        NaN
# 97499   Massachusetts          USA  United States      188.0      102.0
# 98068        Colorado          USA  United States        NaN        NaN
# 99921    Rhode Island          USA  United States      188.0       93.0
# 115973  Massachusetts          USA  United States      183.0       95.0
#
#          died_date
# 3505    1999-12-31
# 12053   1973-02-22
# 14577          NaN
# 16166          NaN
# 18734          NaN
# 29897          NaN
# 34011   2015-09-16
# 46885   1991-03-06
# 50929   2013-05-03
# 51185          NaN
# 52913          NaN
# 55317          NaN
# 57818          NaN
# 61748   1999-03-22
# 62620          NaN
# 62678          NaN
# 68324          NaN
# 68472          NaN
# 68997          NaN
# 77550          NaN
# 84097   2018-11-05
# 94646   2010-07-25
# 95267          NaN
# 96452   2019-10-28
# 97499          NaN
# 98068   1974-08-22
# 99921          NaN
# 115973         NaN

# %%
print("Make sure to smash that like button & subscribe tehehehe")
# Out:
# Make sure to smash that like button & subscribe tehehehe

# %% [markdown]
# Query function

# %%
bios.query('born_country == "USA" and born_city == "Seattle"')
# Out:
#         athlete_id                   name   born_date born_city born_region  \
# 11030        11088          David Halpern  1955-08-18   Seattle  Washington
# 12800        12870            Todd Trewin  1958-04-20   Seattle  Washington
# 15476        15583         Scott McKinley  1968-10-15   Seattle  Washington
# 29079        29293            Joyce Tanac  1950-09-27   Seattle  Washington
# 31135        31371        Bill Kuhlemeier  1908-01-14   Seattle  Washington
# ...            ...                    ...         ...       ...         ...
# 133392      136331          Hans Struzyna  1989-03-31   Seattle  Washington
# 135448      138662  Maude Davis Crossland  2003-03-19   Seattle  Washington
# 136993      140229        Jenell Berhorst  2003-12-13   Seattle  Washington
# 143507      147159         Nevin Harrison  2002-06-02   Seattle  Washington
# 145446      149169       Corinne Stoddard  2001-08-15   Seattle  Washington
#
#        born_country            NOC  height_cm  weight_kg   died_date
# 11030           USA  United States      178.0       79.0         NaN
# 12800           USA  United States      180.0       75.0         NaN
# 15476           USA  United States      183.0       75.0         NaN
# 29079           USA  United States      156.0       49.0         NaN
# 31135           USA  United States        NaN        NaN  2001-07-08
# ...             ...            ...        ...        ...         ...
# 133392          USA  United States      188.0       91.0         NaN
# 135448          USA       Colombia        NaN        NaN         NaN
# 136993          USA  United States        NaN        NaN         NaN
# 143507          USA  United States      175.0       73.0         NaN
# 145446          USA  United States        NaN        NaN         NaN
#
# [102 rows x 10 columns]

# %% [markdown]
# Adding / Removing Columns

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          10
# 2    Tuesday    Espresso          10
# 3    Tuesday       Latte          10
# 4  Wednesday    Espresso          35

# %%
coffee['price'] = 4.99

# %%
coffee['new_price'] = np.where(coffee['Coffee Type'] == 'Espresso',3.99, 5.99)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new_price
# 0      Monday    Espresso          25   4.99       3.99
# 1      Monday       Latte          10   4.99       5.99
# 2     Tuesday    Espresso          10   4.99       3.99
# 3     Tuesday       Latte          10   4.99       5.99
# 4   Wednesday    Espresso          35   4.99       3.99
# 5   Wednesday       Latte          25   4.99       5.99
# 6    Thursday    Espresso          40   4.99       3.99
# 7    Thursday       Latte          30   4.99       5.99
# 8      Friday    Espresso          45   4.99       3.99
# 9      Friday       Latte          35   4.99       5.99
# 10   Saturday    Espresso          45   4.99       3.99
# 11   Saturday       Latte          35   4.99       5.99
# 12     Sunday    Espresso          45   4.99       3.99
# 13     Sunday       Latte          35   4.99       5.99

# %%
coffee.drop(columns=['price'], inplace=True)

# %%
coffee = coffee[['Day', 'Coffee Type', 'Units Sold', 'new_price']]

# %%
coffee['revenue'] = coffee['Units Sold'] * coffee['new_price']

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  revenue
# 0      Monday    Espresso          25       3.99    99.75
# 1      Monday       Latte          10       5.99    59.90
# 2     Tuesday    Espresso          10       3.99    39.90
# 3     Tuesday       Latte          10       5.99    59.90
# 4   Wednesday    Espresso          35       3.99   139.65
# 5   Wednesday       Latte          25       5.99   149.75
# 6    Thursday    Espresso          40       3.99   159.60
# 7    Thursday       Latte          30       5.99   179.70
# 8      Friday    Espresso          45       3.99   179.55
# 9      Friday       Latte          35       5.99   209.65
# 10   Saturday    Espresso          45       3.99   179.55
# 11   Saturday       Latte          35       5.99   209.65
# 12     Sunday    Espresso          45       3.99   179.55
# 13     Sunday       Latte          35       5.99   209.65

# %%
coffee.rename(columns={'new_price':'price'}, inplace=True)

# %%
bios_new = bios.copy()

# %%
bios_new['first_name'] = bios_new['name'].str.split().str[0]

# %%
bios_new.query('first_name == "Keith"')
# Out:
#         athlete_id               name   born_date     born_city  \
# 1897          1907       Keith Hanlon  1966-09-01           NaN
# 3505          3517      Keith Wallace  1961-03-29       Preston
# 6228          6255      Keith Hartley  1940-10-15     Vancouver
# 8898          8946        Keith Mwila  1966-01-01           NaN
# 12053        12118       Keith Hervey  1898-11-03        Fulham
# ...            ...                ...         ...           ...
# 99921       100722       Keith Carney  1970-02-03    Providence
# 102227      103168      Keith Beavers  1983-02-09        London
# 109900      111105  Keith Cumberpatch  1927-08-25  Christchurch
# 115973      117348    Keith Sanderson  1975-02-02      Plymouth
# 122121      124176     Keith Ferguson  1979-09-07          Sale
#
#              born_region born_country            NOC  height_cm  weight_kg  \
# 1897                 NaN          NaN        Ireland        NaN        NaN
# 3505             England          GBR  Great Britain      165.0       51.0
# 6228    British Columbia          CAN         Canada      200.0       85.0
# 8898                 NaN          NaN         Zambia        NaN        NaN
# 12053            England          GBR  Great Britain        NaN        NaN
# ...                  ...          ...            ...        ...        ...
# 99921       Rhode Island          USA  United States      188.0       93.0
# 102227           Ontario          CAN         Canada      185.0       75.0
# 109900        Canterbury          NZL    New Zealand        NaN        NaN
# 115973     Massachusetts          USA  United States      183.0       95.0
# 122121          Victoria          AUS      Australia      176.0       78.0
#
#          died_date first_name
# 1897           NaN      Keith
# 3505    1999-12-31      Keith
# 6228           NaN      Keith
# 8898    1993-01-09      Keith
# 12053   1973-02-22      Keith
# ...            ...        ...
# 99921          NaN      Keith
# 102227         NaN      Keith
# 109900  2013-11-15      Keith
# 115973         NaN      Keith
# 122121         NaN      Keith
#
# [64 rows x 11 columns]

# %%
bios_new['born_datetime'] = pd.to_datetime(bios_new['born_date'])

# %%
bios_new['born_year'] = bios_new['born_datetime'].dt.year

# %%
bios_new[['name','born_year']]
# Out:
#                          name  born_year
# 0       Jean-François Blanchy     1886.0
# 1              Arnaud Boetsch     1969.0
# 2                Jean Borotra     1898.0
# 3             Jacques Brugnon     1895.0
# 4                Albert Canet     1878.0
# ...                       ...        ...
# 145495      Polina Luchnikova     2002.0
# 145496    Valeriya Merkusheva     1999.0
# 145497        Yuliya Smirnova     1998.0
# 145498         André Foussard     1899.0
# 145499          Bill Phillips     1913.0
#
# [145500 rows x 2 columns]

# %%
bios_new.to_csv('./data/bios_new.csv', index=False)

# %%
bios['height_category'] = bios['height_cm'].apply(lambda x: 'short' if x < 165 else ('Average' if x <= 185 else 'tall'))

# %%
def categorize_athlete(row):
    if row['height_cm'] < 175 and row['weight_kg'] < 70:
        return 'Lightweight'
    elif row['height_cm'] < 185 or row['weight_kg'] <= 80:
        return 'Middleweight'
    
    else:
        return 'Heavyweight'
    
bios['Category'] = bios.apply(categorize_athlete, axis=1)

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category      Category
# 0  1960-10-02            tall   Heavyweight
# 1         NaN         Average  Middleweight
# 2  1994-07-17         Average  Middleweight
# 3  1978-03-20         Average   Lightweight
# 4  1930-07-25            tall   Heavyweight

# %% [markdown]
# Merging & Concatenating Data

# %%
nocs = pd.read_csv('./data/noc_regions.csv')

# %%
bios_new = pd.merge(bios , nocs, left_on = 'born_country', right_on='NOC', how='left')

# %%
bios_new.rename(columns={'region': 'born_country_full'}, inplace=True)

# %%
usa = bios[bios['born_country']== 'USA'].copy()
gbr = bios[bios['born_country']== 'GBR'].copy()

# %%
new_df = pd.concat([usa,gbr])

# %%
new_df.tail()
# Out:
#         athlete_id                name   born_date     born_city born_region  \
# 144811      148512  Benjamin Alexander  1983-05-08        London     England
# 144815      148517       Ashley Watson  1993-10-28  Peterborough     England
# 145005      148716     Peder Kongshaug  2001-08-13     Wimbledon     England
# 145319      149041          Axel Brown  1992-04-02     Harrogate     England
# 145388      149111      Jean-Luc Baker  1993-10-07       Burnley     England
#
#        born_country                  NOC  height_cm  weight_kg died_date  \
# 144811          GBR              Jamaica        NaN        NaN       NaN
# 144815          GBR              Jamaica        NaN        NaN       NaN
# 145005          GBR               Norway      184.0       86.0       NaN
# 145319          GBR  Trinidad and Tobago        NaN        NaN       NaN
# 145388          GBR        United States        NaN        NaN       NaN
#
#        height_category      Category
# 144811            tall   Heavyweight
# 144815            tall   Heavyweight
# 145005         Average  Middleweight
# 145319            tall   Heavyweight
# 145388            tall   Heavyweight

# %%
combined_df = pd.merge(results, bios, on='athlete_id', how='left')

# %%
combined_df.head
# Out:
# <bound method NDFrame.head of           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                    None        Slalom, Women (Olympic)
#
#                            as  athlete_id   noc             team  place  \
# 0       Jean-François Blanchy           1   FRA             None   17.0
# 1       Jean-François Blanchy           1   FRA   Jean Montariol    NaN
# 2       Jean-François Blanchy           1   FRA             None   32.0
# 3       Jean-François Blanchy           1   FRA  Jeanne Vaussard    8.0
# 4       Jean-François Blanchy           1   FRA  Jacques Brugnon    4.0
# ...                       ...         ...   ...              ...    ...
# 308403          Marián Skupek      148983   SVK             None   26.0
# 308404          Elsa Fermbäck      148984   SWE             None   28.0
# 308405          Hilma Lövblom      148985   SWE           Sweden   13.0
# 308406          Hilma Lövblom      148985   SWE             None    NaN
# 308407   Charlotta Säfvenberg      148986  None             None   24.0
#
#          tied  ...   born_date   born_city born_region born_country       NOC  \
# 0        True  ...  1886-12-12    Bordeaux     Gironde          FRA    France
# 1       False  ...  1886-12-12    Bordeaux     Gironde          FRA    France
# 2        True  ...  1886-12-12    Bordeaux     Gironde          FRA    France
# 3        True  ...  1886-12-12    Bordeaux     Gironde          FRA    France
# 4       False  ...  1886-12-12    Bordeaux     Gironde          FRA    France
# ...       ...  ...         ...         ...         ...          ...       ...
# 308403  False  ...  2001-07-12     Gelnica      Košice          SVK  Slovakia
# 308404  False  ...  1998-03-28    Vemdalen    Jämtland          SWE    Sweden
# 308405  False  ...  2000-08-16        Täby   Stockholm          SWE    Sweden
# 308406  False  ...  2000-08-16        Täby   Stockholm          SWE    Sweden
# 308407  False  ...  1994-10-07  Kungsbacka     Halland          SWE    Sweden
#
#        height_cm weight_kg   died_date  height_category     Category
# 0            NaN       NaN  1960-10-02             tall  Heavyweight
# 1            NaN       NaN  1960-10-02             tall  Heavyweight
# 2            NaN       NaN  1960-10-02             tall  Heavyweight
# 3            NaN       NaN  1960-10-02             tall  Heavyweight
# 4            NaN       NaN  1960-10-02             tall  Heavyweight
# ...          ...       ...         ...              ...          ...
# 308403     196.0     108.0         NaN             tall  Heavyweight
# 308404       NaN       NaN         NaN             tall  Heavyweight
# 308405       NaN       NaN         NaN             tall  Heavyweight
# 308406       NaN       NaN         NaN             tall  Heavyweight
# 308407       NaN       NaN         NaN             tall  Heavyweight
#
# [308408 rows x 22 columns]>

# %% [markdown]
# Handling Null Values

# %%
coffee.loc[[2,3], 'Units sold'] = np.nan

# %%
coffee['Units Sold'].fillna(coffee['Units Sold'].mean())
# Out:
# 0     25
# 1     10
# 2     10
# 3     10
# 4     35
# 5     25
# 6     40
# 7     30
# 8     45
# 9     35
# 10    45
# 11    35
# 12    45
# 13    35
# Name: Units Sold, dtype: int64

# %%
coffee.dropna(subset=['Units Sold'])
# Out:
#           Day Coffee Type  Units Sold  price  revenue  Units sold
# 0      Monday    Espresso          25   3.99    99.75         NaN
# 1      Monday       Latte          10   5.99    59.90         NaN
# 2     Tuesday    Espresso          10   3.99    39.90         NaN
# 3     Tuesday       Latte          10   5.99    59.90         NaN
# 4   Wednesday    Espresso          35   3.99   139.65         NaN
# 5   Wednesday       Latte          25   5.99   149.75         NaN
# 6    Thursday    Espresso          40   3.99   159.60         NaN
# 7    Thursday       Latte          30   5.99   179.70         NaN
# 8      Friday    Espresso          45   3.99   179.55         NaN
# 9      Friday       Latte          35   5.99   209.65         NaN
# 10   Saturday    Espresso          45   3.99   179.55         NaN
# 11   Saturday       Latte          35   5.99   209.65         NaN
# 12     Sunday    Espresso          45   3.99   179.55         NaN
# 13     Sunday       Latte          35   5.99   209.65         NaN

# %%
coffee[coffee['Units Sold'].notna()]
# Out:
#           Day Coffee Type  Units Sold  price  revenue  Units sold
# 0      Monday    Espresso          25   3.99    99.75         NaN
# 1      Monday       Latte          10   5.99    59.90         NaN
# 2     Tuesday    Espresso          10   3.99    39.90         NaN
# 3     Tuesday       Latte          10   5.99    59.90         NaN
# 4   Wednesday    Espresso          35   3.99   139.65         NaN
# 5   Wednesday       Latte          25   5.99   149.75         NaN
# 6    Thursday    Espresso          40   3.99   159.60         NaN
# 7    Thursday       Latte          30   5.99   179.70         NaN
# 8      Friday    Espresso          45   3.99   179.55         NaN
# 9      Friday       Latte          35   5.99   209.65         NaN
# 10   Saturday    Espresso          45   3.99   179.55         NaN
# 11   Saturday       Latte          35   5.99   209.65         NaN
# 12     Sunday    Espresso          45   3.99   179.55         NaN
# 13     Sunday       Latte          35   5.99   209.65         NaN

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue  Units sold
# 0      Monday    Espresso          25   3.99    99.75         NaN
# 1      Monday       Latte          10   5.99    59.90         NaN
# 2     Tuesday    Espresso          10   3.99    39.90         NaN
# 3     Tuesday       Latte          10   5.99    59.90         NaN
# 4   Wednesday    Espresso          35   3.99   139.65         NaN
# 5   Wednesday       Latte          25   5.99   149.75         NaN
# 6    Thursday    Espresso          40   3.99   159.60         NaN
# 7    Thursday       Latte          30   5.99   179.70         NaN
# 8      Friday    Espresso          45   3.99   179.55         NaN
# 9      Friday       Latte          35   5.99   209.65         NaN
# 10   Saturday    Espresso          45   3.99   179.55         NaN
# 11   Saturday       Latte          35   5.99   209.65         NaN
# 12     Sunday    Espresso          45   3.99   179.55         NaN
# 13     Sunday       Latte          35   5.99   209.65         NaN

# %% [markdown]
# Aggregating Data

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category      Category
# 0  1960-10-02            tall   Heavyweight
# 1         NaN         Average  Middleweight
# 2  1994-07-17         Average  Middleweight
# 3  1978-03-20         Average   Lightweight
# 4  1930-07-25            tall   Heavyweight

# %%
bios['born_city'].value_counts()
# Out:
# born_city
# Budapest           1378
# Moskva (Moscow)     883
# Oslo                708
# Stockholm           629
# Praha (Prague)      600
#                    ...
# Bodrogkisfalud        1
# Ternberg              1
# Klaus                 1
# Plaški                1
# Dulwich Hill          1
# Name: count, Length: 22368, dtype: int64

# %%
bios[bios['born_country']=='USA']['born_region'].value_counts().head(10)
# Out:
# born_region
# California       1634
# New York          990
# Illinois          585
# Pennsylvania      530
# Massachusetts     530
# New Jersey        381
# Texas             368
# Minnesota         365
# Ohio              328
# Michigan          319
# Name: count, dtype: int64

# %% [markdown]
# Groupby Function in Pandas

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].sum()
# Out:
# Coffee Type
# Espresso    245
# Latte       180
# Name: Units Sold, dtype: int64

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].mean()
# Out:
# Coffee Type
# Espresso    35.000000
# Latte       25.714286
# Name: Units Sold, dtype: float64

# %%
coffee.groupby(['Coffee Type', 'Day']).agg({'Units Sold': 'sum', 'price':'mean'})
# Out:
#                        Units Sold  price
# Coffee Type Day
# Espresso    Friday             45   3.99
#             Monday             25   3.99
#             Saturday           45   3.99
#             Sunday             45   3.99
#             Thursday           40   3.99
#             Tuesday            10   3.99
#             Wednesday          35   3.99
# Latte       Friday             35   5.99
#             Monday             10   5.99
#             Saturday           35   5.99
#             Sunday             35   5.99
#             Thursday           30   5.99
#             Tuesday            10   5.99
#             Wednesday          25   5.99

# %% [markdown]
# pivot table

# %%
pivot = coffee.pivot(columns ='Coffee Type', index='Day', values='revenue')

# %%
pivot.sum()
# Out:
# Coffee Type
# Espresso     977.55
# Latte       1078.20
# dtype: float64

# %%
pivot.sum(axis=1)
# Out:
# Day
# Friday       389.20
# Monday       159.65
# Saturday     389.20
# Sunday       389.20
# Thursday     339.30
# Tuesday       99.80
# Wednesday    289.40
# dtype: float64

# %% [markdown]
# Using datetime with Groupby

# %%
bios['born_date'] = pd.to_datetime(bios['born_date'])
bios['month_born'] = bios['born_date'].dt.month
bios['year_born'] = bios['born_date'].dt.year
bios.groupby([bios['year_born'],bios['month_born']])['name'].count().reset_index().sort_values('name', ascending=False)
# Out:
#       year_born  month_born  name
# 1437     1970.0         1.0   239
# 1461     1972.0         1.0   229
# 1629     1986.0         1.0   227
# 1497     1975.0         1.0   227
# 1617     1985.0         1.0   225
# ...         ...         ...   ...
# 95       1857.0         5.0     1
# 96       1857.0         7.0     1
# 97       1857.0         8.0     1
# 98       1857.0         9.0     1
# 1884     2009.0         1.0     1
#
# [1885 rows x 3 columns]

# %% [markdown]
# Advanced Functionality

# %%
latte = coffee[coffee['Coffee Type']=="Latte"].copy()
latte['3day'] = latte['Units Sold'].rolling(3).sum()

# %%
latte
# Out:
#           Day Coffee Type  Units Sold  price  revenue  Units sold   3day
# 1      Monday       Latte          10   5.99    59.90         NaN    NaN
# 3     Tuesday       Latte          10   5.99    59.90         NaN    NaN
# 5   Wednesday       Latte          25   5.99   149.75         NaN   45.0
# 7    Thursday       Latte          30   5.99   179.70         NaN   65.0
# 9      Friday       Latte          35   5.99   209.65         NaN   90.0
# 11   Saturday       Latte          35   5.99   209.65         NaN  100.0
# 13     Sunday       Latte          35   5.99   209.65         NaN  105.0

# %% [markdown]
# Advanced Functionality(cont.)

# %%
# !pip install pyjanitor
# Out:
# Collecting pyjanitor
#   Using cached pyjanitor-0.32.4-py3-none-any.whl.metadata (3.7 kB)
# Collecting natsort (from pyjanitor)
#   Using cached natsort-8.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting pandas-flavor==0.8.1 (from pyjanitor)
#   Using cached pandas_flavor-0.8.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: multipledispatch in c:\users\rahul kate\anaconda3\lib\site-packages (from pyjanitor) (0.6.0)
# Requirement already satisfied: scipy in c:\users\rahul kate\anaconda3\lib\site-packages (from pyjanitor) (1.13.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\rahul kate\anaconda3\lib\site-packages (from pandas-flavor==0.8.1->pyjanitor) (2.2.2)
# Requirement already satisfied: xarray in c:\users\rahul kate\anaconda3\lib\site-packages (from pandas-flavor==0.8.1->pyjanitor) (2023.6.0)
# Requirement already satisfied: six in c:\users\rahul kate\anaconda3\lib\site-packages (from multipledispatch->pyjanitor) (1.16.0)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in c:\users\rahul kate\anaconda3\lib\site-packages (from scipy->pyjanitor) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rahul kate\anaconda3\lib\site-packages (from pandas>=0.23->pandas-flavor==0.8.1->pyjanitor) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rahul kate\anaconda3\lib\site-packages (from pandas>=0.23->pandas-flavor==0.8.1->pyjanitor) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rahul kate\anaconda3\lib\site-packages (from pandas>=0.23->pandas-flavor==0.8.1->pyjanitor) (2023.3)
# Requirement already satisfied: packaging>=21.3 in c:\users\rahul kate\anaconda3\lib\site-packages (from xarray->pandas-flavor==0.8.1->pyjanitor) (24.1)
# Using cached pyjanitor-0.32.4-py3-none-any.whl (220 kB)
# Using cached pandas_flavor-0.8.1-py3-none-any.whl (8.5 kB)
# Using cached natsort-8.4.0-py3-none-any.whl (38 kB)
# Installing collected packages: natsort, pandas-flavor, pyjanitor
# Successfully installed natsort-8.4.0 pandas-flavor-0.8.1 pyjanitor-0.32.4

# %%
import janitor

coffee.clean_names()
# Out:
#           day coffee_type  units_sold  price  revenue  units_sold
# 0      Monday    Espresso          25   3.99    99.75         NaN
# 1      Monday       Latte          10   5.99    59.90         NaN
# 2     Tuesday    Espresso          10   3.99    39.90         NaN
# 3     Tuesday       Latte          10   5.99    59.90         NaN
# 4   Wednesday    Espresso          35   3.99   139.65         NaN
# 5   Wednesday       Latte          25   5.99   149.75         NaN
# 6    Thursday    Espresso          40   3.99   159.60         NaN
# 7    Thursday       Latte          30   5.99   179.70         NaN
# 8      Friday    Espresso          45   3.99   179.55         NaN
# 9      Friday       Latte          35   5.99   209.65         NaN
# 10   Saturday    Espresso          45   3.99   179.55         NaN
# 11   Saturday       Latte          35   5.99   209.65         NaN
# 12     Sunday    Espresso          45   3.99   179.55         NaN
# 13     Sunday       Latte          35   5.99   209.65         NaN

# %%
# !pip install skimpy
# Out:
# Collecting skimpy
#   Downloading skimpy-0.0.19-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: click>=8.1.7 in c:\users\rahul kate\anaconda3\lib\site-packages (from skimpy) (8.1.7)
# Collecting ipykernel>=6.29.5 (from skimpy)
#   Using cached ipykernel-7.1.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting numpy>=2.0.2 (from skimpy)
#   Downloading numpy-2.4.0-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Collecting pandas-stubs>=2.2.2.240807 (from skimpy)
#   Downloading pandas_stubs-2.3.3.251219-py3-none-any.whl.metadata (10 kB)
# Collecting pandas>=2.2.3 (from skimpy)
#   Downloading pandas-2.3.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting polars>=1.17.1 (from skimpy)
#   Downloading polars-1.36.1-py3-none-any.whl.metadata (10 kB)
# Collecting pygments>=2.18.0 (from skimpy)
#   Downloading pygments-2.19.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting rich>=13.9.4 (from skimpy)
#   Downloading rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Collecting typeguard>=4.4.1 (from skimpy)
#   Downloading typeguard-4.4.4-py3-none-any.whl.metadata (3.3 kB)
# Collecting pyarrow>=17.0.0 (from skimpy)
#   Downloading pyarrow-22.0.0-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Collecting pydoclint>=0.6.0 (from skimpy)
#   Downloading pydoclint-0.8.3-py3-none-any.whl.metadata (10 kB)
# Collecting duckdb>=1.2.2 (from skimpy)
#   Downloading duckdb-1.4.3-cp312-cp312-win_amd64.whl.metadata (4.3 kB)
# Requirement already satisfied: colorama in c:\users\rahul kate\anaconda3\lib\site-packages (from click>=8.1.7->skimpy) (0.4.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\rahul kate\anaconda3\lib\site-packages (from ipykernel>=6.29.5->skimpy) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\rahul kate\anaconda3\lib\site-packages (from ipykernel>=6.29.5->skimpy) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\rahul kate\anaconda3\lib\site-packages (from ipykernel>=6.29.5->skimpy) (8.27.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\rahul kate\anaconda3\lib\site-packages (from ipykernel>=6.29.5->skimpy) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\rahul kate\anaconda3\lib\site-packages (from ipykernel>=6.29.5->skimpy) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\rahul kate\anaconda3\lib\site-packages (from ipykernel>=6.29.5->skimpy) (0.1.6)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\rahul kate\anaconda3\lib\site-packages (from ipykernel>=6.29.5->skimpy) (1.6.0)
# Requirement already satisfied: packaging>=22 in c:\users\rahul kate\anaconda3\lib\site-packages (from ipykernel>=6.29.5->skimpy) (24.1)
# Requirement already satisfied: psutil>=5.7 in c:\users\rahul kate\anaconda3\lib\site-packages (from ipykernel>=6.29.5->skimpy) (5.9.0)
# Requirement already satisfied: pyzmq>=25 in c:\users\rahul kate\anaconda3\lib\site-packages (from ipykernel>=6.29.5->skimpy) (25.1.2)
# Requirement already satisfied: tornado>=6.2 in c:\users\rahul kate\anaconda3\lib\site-packages (from ipykernel>=6.29.5->skimpy) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\rahul kate\anaconda3\lib\site-packages (from ipykernel>=6.29.5->skimpy) (5.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rahul kate\anaconda3\lib\site-packages (from pandas>=2.2.3->skimpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rahul kate\anaconda3\lib\site-packages (from pandas>=2.2.3->skimpy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rahul kate\anaconda3\lib\site-packages (from pandas>=2.2.3->skimpy) (2023.3)
# Collecting numpy>=2.0.2 (from skimpy)
#   Downloading numpy-2.3.5-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting types-pytz>=2022.1.1 (from pandas-stubs>=2.2.2.240807->skimpy)
#   Downloading types_pytz-2025.2.0.20251108-py3-none-any.whl.metadata (1.7 kB)
# Collecting polars-runtime-32==1.36.1 (from polars>=1.17.1->skimpy)
#   Downloading polars_runtime_32-1.36.1-cp39-abi3-win_amd64.whl.metadata (1.5 kB)
# Collecting docstring_parser_fork>=0.0.12 (from pydoclint>=0.6.0->skimpy)
#   Downloading docstring_parser_fork-0.0.14-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rahul kate\anaconda3\lib\site-packages (from rich>=13.9.4->skimpy) (2.2.0)
# Collecting typing_extensions>=4.14.0 (from typeguard>=4.4.1->skimpy)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: decorator in c:\users\rahul kate\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\rahul kate\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\rahul kate\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (3.0.43)
# Requirement already satisfied: stack-data in c:\users\rahul kate\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.2.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\rahul kate\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.29.5->skimpy) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\rahul kate\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.29.5->skimpy) (305.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rahul kate\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->skimpy) (0.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\rahul kate\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.2.3->skimpy) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\rahul kate\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\rahul kate\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.2.5)
# Requirement already satisfied: executing in c:\users\rahul kate\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\rahul kate\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\rahul kate\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.2.2)
# Downloading skimpy-0.0.19-py3-none-any.whl (17 kB)
# Downloading duckdb-1.4.3-cp312-cp312-win_amd64.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.3 MB 1.5 MB/s eta 0:00:08
#    -- ------------------------------------- 0.8/12.3 MB 1.6 MB/s eta 0:00:08
#    --- ------------------------------------ 1.0/12.3 MB 1.6 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.3/12.3 MB 1.4 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.8/12.3 MB 1.5 MB/s eta 0:00:07
#    ------- -------------------------------- 2.4/12.3 MB 1.7 MB/s eta 0:00:06
#    --------- ------------------------------ 2.9/12.3 MB 1.8 MB/s eta 0:00:06
#    ---------- ----------------------------- 3.1/12.3 MB 1.9 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.4/12.3 MB 1.7 MB/s eta 0:00:06
#    ------------- -------------------------- 4.2/12.3 MB 1.9 MB/s eta 0:00:05
#    --------------- ------------------------ 4.7/12.3 MB 1.9 MB/s eta 0:00:04
#    ----------------- ---------------------- 5.2/12.3 MB 2.0 MB/s eta 0:00:04
#    ------------------ --------------------- 5.8/12.3 MB 2.0 MB/s eta 0:00:04
#    -------------------- ------------------- 6.3/12.3 MB 2.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 7.1/12.3 MB 2.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 7.3/12.3 MB 2.2 MB/s eta 0:00:03
#    ------------------------- -------------- 7.9/12.3 MB 2.2 MB/s eta 0:00:03
#    --------------------------- ------------ 8.4/12.3 MB 2.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.9/12.3 MB 2.2 MB/s eta 0:00:02
#    ------------------------------ --------- 9.4/12.3 MB 2.2 MB/s eta 0:00:02
#    -------------------------------- ------- 10.0/12.3 MB 2.2 MB/s eta 0:00:02
#    --------------------------------- ------ 10.2/12.3 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.7/12.3 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------ --- 11.3/12.3 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 11.5/12.3 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 11.8/12.3 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.3 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 2.1 MB/s eta 0:00:00
# Using cached ipykernel-7.1.0-py3-none-any.whl (117 kB)
# Downloading pandas-2.3.3-cp312-cp312-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.0 MB 2.1 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.3/11.0 MB 2.1 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.6/11.0 MB 2.0 MB/s eta 0:00:05
#    ------- -------------------------------- 2.1/11.0 MB 2.1 MB/s eta 0:00:05
#    --------- ------------------------------ 2.6/11.0 MB 2.2 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.1/11.0 MB 2.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.1/11.0 MB 2.1 MB/s eta 0:00:04
#    ------------ --------------------------- 3.4/11.0 MB 1.8 MB/s eta 0:00:05
#    -------------- ------------------------- 3.9/11.0 MB 1.9 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.5/11.0 MB 1.9 MB/s eta 0:00:04
#    ----------------- ---------------------- 4.7/11.0 MB 1.9 MB/s eta 0:00:04
#    ------------------- -------------------- 5.2/11.0 MB 2.0 MB/s eta 0:00:03
#    -------------------- ------------------- 5.5/11.0 MB 1.9 MB/s eta 0:00:03
#    --------------------- ------------------ 6.0/11.0 MB 1.9 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.3/11.0 MB 1.9 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.6/11.0 MB 1.9 MB/s eta 0:00:03
#    ------------------------- -------------- 7.1/11.0 MB 1.9 MB/s eta 0:00:03
#    --------------------------- ------------ 7.6/11.0 MB 1.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.1/11.0 MB 1.9 MB/s eta 0:00:02
#    ------------------------------ --------- 8.4/11.0 MB 1.9 MB/s eta 0:00:02
#    -------------------------------- ------- 8.9/11.0 MB 1.9 MB/s eta 0:00:02
#    --------------------------------- ------ 9.2/11.0 MB 2.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/11.0 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 10.2/11.0 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 2.0 MB/s eta 0:00:00
# Downloading pandas_stubs-2.3.3.251219-py3-none-any.whl (163 kB)
# Downloading numpy-2.3.5-cp312-cp312-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.8 MB 2.4 MB/s eta 0:00:06
#    -- ------------------------------------- 0.8/12.8 MB 1.5 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.8/12.8 MB 3.0 MB/s eta 0:00:04
#    -------- ------------------------------- 2.6/12.8 MB 3.0 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.4/12.8 MB 3.2 MB/s eta 0:00:03
#    ------------- -------------------------- 4.2/12.8 MB 3.4 MB/s eta 0:00:03
#    ------------- -------------------------- 4.5/12.8 MB 3.3 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.5/12.8 MB 3.4 MB/s eta 0:00:03
#    ------------------- -------------------- 6.3/12.8 MB 3.4 MB/s eta 0:00:02
#    --------------------- ------------------ 6.8/12.8 MB 3.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 7.6/12.8 MB 3.4 MB/s eta 0:00:02
#    -------------------------- ------------- 8.4/12.8 MB 3.4 MB/s eta 0:00:02
#    --------------------------- ------------ 8.9/12.8 MB 3.4 MB/s eta 0:00:02
#    ------------------------------ --------- 9.7/12.8 MB 3.4 MB/s eta 0:00:01
#    -------------------------------- ------- 10.5/12.8 MB 3.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.3/12.8 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 12.1/12.8 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 3.5 MB/s eta 0:00:00
# Downloading polars-1.36.1-py3-none-any.whl (802 kB)
#    ---------------------------------------- 0.0/802.4 kB ? eta -:--:--
#    -------------------------- ------------- 524.3/802.4 kB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 802.4/802.4 kB 3.1 MB/s eta 0:00:00
# Downloading polars_runtime_32-1.36.1-cp39-abi3-win_amd64.whl (44.5 MB)
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.5/44.5 MB 2.4 MB/s eta 0:00:19
#    - -------------------------------------- 1.3/44.5 MB 3.5 MB/s eta 0:00:13
#    - -------------------------------------- 2.1/44.5 MB 3.6 MB/s eta 0:00:12
#    -- ------------------------------------- 2.6/44.5 MB 3.4 MB/s eta 0:00:13
#    --- ------------------------------------ 3.4/44.5 MB 3.4 MB/s eta 0:00:13
#    --- ------------------------------------ 3.9/44.5 MB 3.5 MB/s eta 0:00:12
#    ---- ----------------------------------- 4.5/44.5 MB 3.2 MB/s eta 0:00:13
#    ---- ----------------------------------- 4.7/44.5 MB 3.0 MB/s eta 0:00:14
#    ---- ----------------------------------- 5.5/44.5 MB 3.0 MB/s eta 0:00:13
#    ----- ---------------------------------- 6.3/44.5 MB 3.1 MB/s eta 0:00:13
#    ------ --------------------------------- 7.1/44.5 MB 3.2 MB/s eta 0:00:12
#    ------- -------------------------------- 8.1/44.5 MB 3.3 MB/s eta 0:00:12
#    -------- ------------------------------- 8.9/44.5 MB 3.4 MB/s eta 0:00:11
#    -------- ------------------------------- 10.0/44.5 MB 3.4 MB/s eta 0:00:11
#    --------- ------------------------------ 11.0/44.5 MB 3.5 MB/s eta 0:00:10
#    ---------- ----------------------------- 11.8/44.5 MB 3.6 MB/s eta 0:00:10
#    ----------- ---------------------------- 12.8/44.5 MB 3.6 MB/s eta 0:00:09
#    ------------ --------------------------- 13.6/44.5 MB 3.7 MB/s eta 0:00:09
#    ------------ --------------------------- 14.2/44.5 MB 3.7 MB/s eta 0:00:09
#    ------------- -------------------------- 14.7/44.5 MB 3.6 MB/s eta 0:00:09
#    ------------- -------------------------- 15.2/44.5 MB 3.5 MB/s eta 0:00:09
#    -------------- ------------------------- 16.3/44.5 MB 3.6 MB/s eta 0:00:08
#    --------------- ------------------------ 17.0/44.5 MB 3.6 MB/s eta 0:00:08
#    ---------------- ----------------------- 17.8/44.5 MB 3.6 MB/s eta 0:00:08
#    ---------------- ----------------------- 18.6/44.5 MB 3.6 MB/s eta 0:00:08
#    ----------------- ---------------------- 19.4/44.5 MB 3.6 MB/s eta 0:00:07
#    ------------------ --------------------- 20.2/44.5 MB 3.6 MB/s eta 0:00:07
#    ------------------- -------------------- 21.2/44.5 MB 3.7 MB/s eta 0:00:07
#    ------------------- -------------------- 22.0/44.5 MB 3.7 MB/s eta 0:00:07
#    -------------------- ------------------- 23.1/44.5 MB 3.7 MB/s eta 0:00:06
#    --------------------- ------------------ 23.6/44.5 MB 3.7 MB/s eta 0:00:06
#    --------------------- ------------------ 24.4/44.5 MB 3.7 MB/s eta 0:00:06
#    ---------------------- ----------------- 25.2/44.5 MB 3.7 MB/s eta 0:00:06
#    ----------------------- ---------------- 26.0/44.5 MB 3.7 MB/s eta 0:00:06
#    ------------------------ --------------- 27.0/44.5 MB 3.7 MB/s eta 0:00:05
#    ------------------------ --------------- 27.8/44.5 MB 3.7 MB/s eta 0:00:05
#    ------------------------- -------------- 28.6/44.5 MB 3.7 MB/s eta 0:00:05
#    -------------------------- ------------- 29.1/44.5 MB 3.7 MB/s eta 0:00:05
#    -------------------------- ------------- 29.9/44.5 MB 3.7 MB/s eta 0:00:04
#    --------------------------- ------------ 30.7/44.5 MB 3.7 MB/s eta 0:00:04
#    ---------------------------- ----------- 31.5/44.5 MB 3.7 MB/s eta 0:00:04
#    ----------------------------- ---------- 32.2/44.5 MB 3.7 MB/s eta 0:00:04
#    ----------------------------- ---------- 33.0/44.5 MB 3.7 MB/s eta 0:00:04
#    ------------------------------ --------- 33.8/44.5 MB 3.7 MB/s eta 0:00:03
#    ------------------------------- -------- 34.6/44.5 MB 3.7 MB/s eta 0:00:03
#    -------------------------------- ------- 35.7/44.5 MB 3.7 MB/s eta 0:00:03
#    -------------------------------- ------- 36.4/44.5 MB 3.7 MB/s eta 0:00:03
#    --------------------------------- ------ 37.0/44.5 MB 3.7 MB/s eta 0:00:03
#    --------------------------------- ------ 37.7/44.5 MB 3.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 38.5/44.5 MB 3.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 39.6/44.5 MB 3.7 MB/s eta 0:00:02
#    ------------------------------------ --- 40.4/44.5 MB 3.7 MB/s eta 0:00:02
#    ------------------------------------- -- 41.2/44.5 MB 3.7 MB/s eta 0:00:01
#    ------------------------------------- -- 41.9/44.5 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 43.0/44.5 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  43.8/44.5 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 44.5/44.5 MB 3.7 MB/s eta 0:00:00
# Downloading pyarrow-22.0.0-cp312-cp312-win_amd64.whl (28.0 MB)
#    ---------------------------------------- 0.0/28.0 MB ? eta -:--:--
#    - -------------------------------------- 0.8/28.0 MB 4.8 MB/s eta 0:00:06
#    -- ------------------------------------- 1.6/28.0 MB 4.0 MB/s eta 0:00:07
#    -- ------------------------------------- 2.1/28.0 MB 3.3 MB/s eta 0:00:08
#    --- ------------------------------------ 2.6/28.0 MB 3.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 3.7/28.0 MB 3.5 MB/s eta 0:00:07
#    ------ --------------------------------- 4.5/28.0 MB 3.6 MB/s eta 0:00:07
#    ------- -------------------------------- 5.5/28.0 MB 3.7 MB/s eta 0:00:07
#    -------- ------------------------------- 6.3/28.0 MB 3.9 MB/s eta 0:00:06
#    ---------- ----------------------------- 7.3/28.0 MB 3.9 MB/s eta 0:00:06
#    ----------- ---------------------------- 8.1/28.0 MB 3.9 MB/s eta 0:00:06
#    ------------ --------------------------- 8.9/28.0 MB 3.9 MB/s eta 0:00:05
#    ------------- -------------------------- 9.7/28.0 MB 3.9 MB/s eta 0:00:05
#    --------------- ------------------------ 10.7/28.0 MB 4.0 MB/s eta 0:00:05
#    ---------------- ----------------------- 11.3/28.0 MB 3.9 MB/s eta 0:00:05
#    ----------------- ---------------------- 12.3/28.0 MB 3.9 MB/s eta 0:00:04
#    ------------------ --------------------- 13.1/28.0 MB 4.0 MB/s eta 0:00:04
#    ------------------- -------------------- 13.9/28.0 MB 4.0 MB/s eta 0:00:04
#    --------------------- ------------------ 14.9/28.0 MB 4.0 MB/s eta 0:00:04
#    ---------------------- ----------------- 15.7/28.0 MB 4.0 MB/s eta 0:00:04
#    ----------------------- ---------------- 16.5/28.0 MB 3.9 MB/s eta 0:00:03
#    ------------------------ --------------- 17.3/28.0 MB 3.9 MB/s eta 0:00:03
#    ------------------------- -------------- 17.8/28.0 MB 3.9 MB/s eta 0:00:03
#    -------------------------- ------------- 18.9/28.0 MB 3.9 MB/s eta 0:00:03
#    ---------------------------- ----------- 19.7/28.0 MB 3.9 MB/s eta 0:00:03
#    ----------------------------- ---------- 20.4/28.0 MB 3.9 MB/s eta 0:00:02
#    ------------------------------ --------- 21.2/28.0 MB 3.9 MB/s eta 0:00:02
#    ------------------------------- -------- 21.8/28.0 MB 3.8 MB/s eta 0:00:02
#    -------------------------------- ------- 22.5/28.0 MB 3.8 MB/s eta 0:00:02
#    --------------------------------- ------ 23.3/28.0 MB 3.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 23.9/28.0 MB 3.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 24.6/28.0 MB 3.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 25.2/28.0 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------- -- 26.0/28.0 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 26.7/28.0 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 27.3/28.0 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  27.5/28.0 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 28.0/28.0 MB 3.6 MB/s eta 0:00:00
# Downloading pydoclint-0.8.3-py3-none-any.whl (79 kB)
# Downloading pygments-2.19.2-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ----------------- ---------------------- 0.5/1.2 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 4.1 MB/s eta 0:00:00
# Downloading rich-14.2.0-py3-none-any.whl (243 kB)
# Downloading typeguard-4.4.4-py3-none-any.whl (34 kB)
# Downloading docstring_parser_fork-0.0.14-py3-none-any.whl (43 kB)
# Downloading types_pytz-2025.2.0.20251108-py3-none-any.whl (10 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Installing collected packages: typing_extensions, types-pytz, pygments, pyarrow, polars-runtime-32, numpy, duckdb, docstring_parser_fork, typeguard, rich, pydoclint, polars, pandas-stubs, pandas, ipykernel, skimpy
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.15.1
#     Uninstalling Pygments-2.15.1:
#       Successfully uninstalled Pygments-2.15.1
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 16.1.0
#     Uninstalling pyarrow-16.1.0:
#       Successfully uninstalled pyarrow-16.1.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: rich
#     Found existing installation: rich 13.7.1
#     Uninstalling rich-13.7.1:
#       Successfully uninstalled rich-13.7.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.28.0
#     Uninstalling ipykernel-6.28.0:
#       Successfully uninstalled ipykernel-6.28.0
# Successfully installed docstring_parser_fork-0.0.14 duckdb-1.4.3 ipykernel-7.1.0 numpy-2.3.5 pandas-2.3.3 pandas-stubs-2.3.3.251219 polars-1.36.1 polars-runtime-32-1.36.1 pyarrow-22.0.0 pydoclint-0.8.3 pygments-2.19.2 rich-14.2.0 skimpy-0.0.19 typeguard-4.4.4 types-pytz-2025.2.0.20251108 typing_extensions-4.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.3.5 which is incompatible.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.3.5 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.5 which is incompatible.
# scipy 1.13.1 requires numpy<2.3,>=1.22.4, but you have numpy 2.3.5 which is incompatible.
# spyder-kernels 2.5.0 requires ipykernel<7,>=6.23.2; python_version >= "3.8", but you have ipykernel 7.1.0 which is incompatible.
# streamlit 1.37.1 requires rich<14,>=10.14.0, but you have rich 14.2.0 which is incompatible.

# %%
from skimpy import skim

skim(results)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 308408 │ │ string      │ 7     │                                                          │
# │ │ Number of columns │ 11     │ │ float64     │ 2     │                                                          │
# │ └───────────────────┴────────┘ │ int32       │ 1     │                                                          │
# │                                │ bool        │ 1     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓  │
# │ ┃ column      ┃ NA    ┃ NA %               ┃ mean  ┃ sd    ┃ p0   ┃ p25   ┃ p50   ┃ p75    ┃ p100   ┃ hist   ┃  │
# │ ┡━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩  │
# │ │ year        │  2601 │ 0.8433633368784208 │  1982 │ 30.98 │ 1896 │  1964 │  1992 │   2008 │   2022 │ ▁▂▂▅▇▇ │  │
# │ │ athlete_id  │     0 │                  0 │ 72620 │ 41290 │    1 │ 34410 │ 73740 │ 107200 │ 149000 │ ▆▇▆▇▇▅ │  │
# │ │ place       │ 25215 │   8.17585795439807 │  16.1 │ 19.32 │    1 │     5 │     9 │     20 │    185 │   ▇▁   │  │
# │ └─────────────┴───────┴────────────────────┴───────┴───────┴──────┴───────┴───────┴────────┴────────┴────────┘  │
# │                                                      bool                                                       │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column                  ┃ true                 ┃ true rate                        ┃ hist                   ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ tied                    │                45940 │                             0.15 │         ▇    ▁         │  │
# │ └─────────────────────────┴──────────────────────┴──────────────────────────────────┴────────────────────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┓  │
# │ ┃          ┃        ┃          ┃          ┃          ┃          ┃          ┃ chars    ┃ words    ┃ total     ┃  │
# │ ┃ column   ┃ NA     ┃ NA %     ┃ shortest ┃ longest  ┃ min      ┃ max      ┃ per row  ┃ per row  ┃ words     ┃  │
# │ ┡━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━┩  │
# │ │ type     │   2601 │ 0.843363 │ Summer   │ Summer   │ Summer   │ Winter   │        6 │     0.99 │    305807 │  │
# │ │          │        │ 33687842 │          │          │          │          │          │          │           │  │
# │ │          │        │       08 │          │          │          │          │          │          │           │  │
# │ │ discipli │      1 │ 0.000324 │ Golf     │ Short    │ 3-on-3   │ Wrestlin │     16.7 │        2 │    610211 │  │
# │ │ ne       │        │ 24580425 │          │ Track    │ Ice      │ g        │          │          │           │  │
# │ │          │        │   929287 │          │ Speed    │ Hockey   │          │          │          │           │  │
# │ │          │        │          │          │ Skating  │ (Ice     │          │          │          │           │  │
# │ │          │        │          │          │ (Skating │ Hockey)  │          │          │          │           │  │
# │ │          │        │          │          │ )        │          │          │          │          │           │  │
# │ │ event    │      0 │        0 │ Polo     │ 26th     │ 0-½ Ton, │ ≤85      │     30.1 │      4.2 │   1303323 │  │
# │ │          │        │          │          │ Federal  │ Open     │ kilogram │          │          │           │  │
# │ │          │        │          │          │ Festival │ (Olympic │ s, Greco │          │          │           │  │
# │ │          │        │          │          │ ,        │ )        │ Roman,   │          │          │           │  │
# │ │          │        │          │          │ Society  │          │ Boys     │          │          │           │  │
# │ │          │        │          │          │ and      │          │ (YOG)    │          │          │           │  │
# │ │          │        │          │          │ Associat │          │          │          │          │           │  │
# │ │          │        │          │          │ ion      │          │          │          │          │           │  │
# │ │          │        │          │          │ Contests │          │          │          │          │           │  │
# │ │          │        │          │          │ ,        │          │          │          │          │           │  │
# │ │          │        │          │          │ Non-Simu │          │          │          │          │           │  │
# │ │          │        │          │          │ ltaneous │          │          │          │          │           │  │
# │ │          │        │          │          │ ,        │          │          │          │          │           │  │
# │ │          │        │          │          │ Shooting │          │          │          │          │           │  │
# │ │          │        │          │          │ Champion │          │          │          │          │           │  │
# │ │          │        │          │          │ ships,   │          │          │          │          │           │  │
# │ │          │        │          │          │ Honorary │          │          │          │          │           │  │
# │ │          │        │          │          │ Members  │          │          │          │          │           │  │
# │ │          │        │          │          │ and      │          │          │          │          │           │  │
# │ │          │        │          │          │ Associat │          │          │          │          │           │  │
# │ │          │        │          │          │ es, Men  │          │          │          │          │           │  │
# │ │          │        │          │          │ (Olympic │          │          │          │          │           │  │
# │ │          │        │          │          │ (non-med │          │          │          │          │           │  │
# │ │          │        │          │          │ al))     │          │          │          │          │           │  │
# │ │ as       │      0 │        0 │ SB       │ Georges, │ A J Kitt │ Аlex     │       14 │      2.1 │    634574 │  │
# │ │          │        │          │          │ Marquis  │          │ Halcheni │          │          │           │  │
# │ │          │        │          │          │ de       │          │ uk       │          │          │           │  │
# │ │          │        │          │          │ Créqui-M │          │          │          │          │           │  │
# │ │          │        │          │          │ ontfort  │          │          │          │          │           │  │
# │ │          │        │          │          │ de       │          │          │          │          │           │  │
# │ │          │        │          │          │ Courtivr │          │          │          │          │           │  │
# │ │          │        │          │          │ on       │          │          │          │          │           │  │
# │ │ noc      │      1 │ 0.000324 │ FRA      │ FRA      │ AFG      │ ZIM      │        3 │        1 │    308407 │  │
# │ │          │        │ 24580425 │          │          │          │          │          │          │           │  │
# │ │          │        │   929287 │          │          │          │          │          │          │           │  │
# │ │ team     │ 186694 │ 60.53474 │ C        │ Victoria │ 't       │ Ștefan   │     10.2 │     0.62 │    190405 │  │
# │ │          │        │ 61803844 │          │ n        │ Soulaiky │ Vasile   │          │          │           │  │
# │ │          │        │       24 │          │ Football │          │          │          │          │           │  │
# │ │          │        │          │          │ League/V │          │          │          │          │           │  │
# │ │          │        │          │          │ ictorian │          │          │          │          │           │  │
# │ │          │        │          │          │          │          │          │          │          │           │  │
# │ │          │        │          │          │ Football │          │          │          │          │           │  │
# │ │          │        │          │          │ Associat │          │          │          │          │           │  │
# │ │          │        │          │          │ ion      │          │          │          │          │           │  │
# │ │ medal    │ 264269 │ 85.68811 │ Gold     │ Bronze   │ Bronze   │ Silver   │     5.33 │     0.14 │     44139 │  │
# │ │          │        │ 44457990 │          │          │          │          │          │          │           │  │
# │ │          │        │        7 │          │          │          │          │          │          │           │  │
# │ └──────────┴────────┴──────────┴──────────┴──────────┴──────────┴──────────┴──────────┴──────────┴───────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   14 non-null     int64
#  3   price        14 non-null     float64
#  4   revenue      14 non-null     float64
#  5   Units sold   0 non-null      float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 804.0+ bytes

# %% [markdown]
# New Functionality

# %%
results_numpy = pd.read_csv('./data/results.csv')

results_arrow = pd.read_csv('./data/results.csv', engine='pyarrow', dtype_backend='pyarrow')

# %%
results_numpy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        305807 non-null  float64
#  1   type        305807 non-null  object
#  2   discipline  308407 non-null  object
#  3   event       308408 non-null  object
#  4   as          308408 non-null  object
#  5   athlete_id  308408 non-null  int64
#  6   noc         308407 non-null  object
#  7   team        121714 non-null  object
#  8   place       283193 non-null  float64
#  9   tied        308408 non-null  bool
#  10  medal       44139 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(7)
# memory usage: 23.8+ MB

# %%
results_arrow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        305807 non-null  double[pyarrow]
#  1   type        305807 non-null  string[pyarrow]
#  2   discipline  308407 non-null  string[pyarrow]
#  3   event       308408 non-null  string[pyarrow]
#  4   as          308408 non-null  string[pyarrow]
#  5   athlete_id  308408 non-null  int64[pyarrow]
#  6   noc         308407 non-null  string[pyarrow]
#  7   team        121714 non-null  string[pyarrow]
#  8   place       283193 non-null  double[pyarrow]
#  9   tied        308408 non-null  bool[pyarrow]
#  10  medal       44139 non-null   string[pyarrow]
# dtypes: bool[pyarrow](1), double[pyarrow](2), int64[pyarrow](1), string[pyarrow](7)
# memory usage: 37.5 MB

# %%
filtered_bios = bios[(bios['born_region'] == 'New Hampshire') | (bios['born_city'] == 'San Francisco')]

bios.head()
# Out:
#    athlete_id                   name  born_date    born_city  \
# 0           1  Jean-François Blanchy 1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch 1969-04-01       Meulan
# 2           3           Jean Borotra 1898-08-13     Biarritz
# 3           4        Jacques Brugnon 1895-05-11  Paris VIIIe
# 4           5           Albert Canet 1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category      Category  month_born  year_born
# 0  1960-10-02            tall   Heavyweight        12.0     1886.0
# 1         NaN         Average  Middleweight         4.0     1969.0
# 2  1994-07-17         Average  Middleweight         8.0     1898.0
# 3  1978-03-20         Average   Lightweight         5.0     1895.0
# 4  1930-07-25            tall   Heavyweight         4.0     1878.0

# %%
import pandas as pd

data = {
    'Date': ['2024-05-01', '2024-05-01', '2024-05-01', '2024-05-02', '2024-05-02', '2024-05-03', '2024-05-03', '2024-05-03'],
    'Item': ['Apple', 'Banana', 'Orange', 'Apple', 'Banana', 'Orange', 'Apple', 'Orange'],
    'Units Sold': [30, 21, 15, 40, 34, 20, 45, 25],
    'Price Per Unit': [1.0, 0.5, 0.75, 1.0, 0.5, 0.75, 1.0, 0.75],
    'Salesperson': ['John', 'John', 'John', 'Alice', 'Alice', 'John', 'Alice', 'John']
}

df = pd.DataFrame(data)

df
# Out:
#          Date    Item  Units Sold  Price Per Unit Salesperson
# 0  2024-05-01   Apple          30            1.00        John
# 1  2024-05-01  Banana          21            0.50        John
# 2  2024-05-01  Orange          15            0.75        John
# 3  2024-05-02   Apple          40            1.00       Alice
# 4  2024-05-02  Banana          34            0.50       Alice
# 5  2024-05-03  Orange          20            0.75        John
# 6  2024-05-03   Apple          45            1.00       Alice
# 7  2024-05-03  Orange          25            0.75        John

# %%
pivot_table = pd.pivot_table(df, values='Units Sold', index='Date', columns='Item', aggfunc='sum')

pivot_table
# Out:
# Item        Apple  Banana  Orange
# Date
# 2024-05-01   30.0    21.0    15.0
# 2024-05-02   40.0    34.0     NaN
# 2024-05-03   45.0     NaN    45.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

bios_filtered = bios.dropna(subset=['height_cm'])

plt.figure(figsize=(10, 6))
plt.hist(bios_filtered['height_cm'], bins=20, color='blue', edgecolor='black')

plt.title('Distribution of Athlete Heights in Olympics')
plt.xlabel('Height in cm')
plt.ylabel('Number of Athletes')
plt.grid(True)

plt.yscale('log')

plt.show()
